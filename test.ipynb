# %%
import os, sys
sys.path.insert(0, os.path.join(os.getcwd(), "src"))

# %%
from bac.manifest import Manifest

test = Manifest("./out/test")

# %%
from bac.algorithms.actor_critic import BootstrappedDDPG
from bac.environments.pendulum import Pendulum

test.bootstrapped("ddpg_pendulum", Pendulum, BootstrappedDDPG, steps=200_000)

# %%
test.plot_bootstrapped("ddpg_pendulum")
