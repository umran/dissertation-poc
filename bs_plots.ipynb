# %%
import os, sys
sys.path.insert(0, os.path.join(os.getcwd(), "src"))

# %%
from bac.manifest import Manifest

prod = Manifest("./out/prod")

# %%
prod.plot_bootstrapped("ddpg_hopper")

# %%
prod.plot_bootstrapped("ddpg_walker")

# %%
prod.plot_bootstrapped("td3_hopper")

# %%
prod.plot_bootstrapped("td3_walker")
