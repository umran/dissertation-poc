# %%
import os, sys
sys.path.insert(0, os.path.join(os.getcwd(), "src"))

# %%
from bac.manifest import Manifest

prod = Manifest("./out/prod")

# %%
prod.plot_comparison("td3_pendulum", truncate_after=200_000)
prod.plot_comparison("td3_pendulum")

# %%
prod.plot_ablation("td3_pendulum", truncate_after=200_000)
prod.plot_ablation("td3_pendulum")

# %%
prod.plot_comparison("td3_inverted_pendulum", truncate_after=200_000)
prod.plot_comparison("td3_inverted_pendulum")

# %%
prod.plot_ablation("td3_inverted_pendulum", truncate_after=200_000)
prod.plot_ablation("td3_inverted_pendulum")

# %%
prod.plot_comparison("td3_inverted_double_pendulum", truncate_after=200_000)
prod.plot_comparison("td3_inverted_double_pendulum")

# %%
prod.plot_ablation("td3_inverted_double_pendulum", truncate_after=200_000)
prod.plot_ablation("td3_inverted_double_pendulum")
# Out:
# /Users/umran/dissertation/poc/src/bac/util.py:68: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
